# %%
import tensorflow as tf

# %%
print("tensorflow version is ",tf.__version__)
# Out:
# tensorflow version is  2.17.0

# %%
mydataset= tf.keras.datasets.mnist

# %%
(x_train,y_train),(x_test,y_test)=mydataset.load_data()
x_train,x_test =x_train/255.0, x_test/255.0

# %%
print("min value is:",x_train.min())
print("max_value is:",x_train.max())
# Out:
# min value is: 0.0
# max_value is: 1.0

# %%
mymodel = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10)
])

# %%
prediction = mymodel(x_train[:1]).numpy()
prediction
# Out:
# array([[-0.38002792,  0.6904933 , -0.5236687 , -0.6960621 ,  0.3195312 ,
#         -0.2175833 , -0.4757576 ,  0.07790209, -0.7070159 ,  0.41853282]],
#       dtype=float32)

# %%
tf.nn.softmax(prediction).numpy()
# Out:
# array([[0.07074976, 0.20636994, 0.06128336, 0.05157902, 0.14240973,
#         0.08322883, 0.06429099, 0.1118411 , 0.05101712, 0.15723003]],
#       dtype=float32)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
loss_fn(y_train[:1],prediction).numpy()
# Out:
# 2.4861615

# %%
mymodel.compile(optimizer='adam',
                loss=loss_fn,
                metrics=['accuracy'])

# %%
mymodel.fit(x_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 590us/step - accuracy: 0.8608 - loss: 0.4859
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 577us/step - accuracy: 0.9553 - loss: 0.1476
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 582us/step - accuracy: 0.9692 - loss: 0.1037
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 584us/step - accuracy: 0.9740 - loss: 0.0845
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 598us/step - accuracy: 0.9778 - loss: 0.0731

# %%
mymodel.evaluate(x_test,y_test,verbose=2)
# Out:
# 313/313 - 0s - 417us/step - accuracy: 0.9785 - loss: 0.0700
# [0.07004012912511826, 0.9785000085830688]
